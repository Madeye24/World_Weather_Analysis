# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)


# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
    # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
    # Parse out the needed data.
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']
    # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
    # Append the city information into city_data list.
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })

        # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

    # Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | kaitangata
# Processing Record 4 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | vila velha
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | ahipara
# Processing Record 13 of Set 1 | hithadhoo
# Processing Record 14 of Set 1 | alto araguaia
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | ofeherto
# Processing Record 17 of Set 1 | miramar
# Processing Record 18 of Set 1 | georgetown
# Processing Record 19 of Set 1 | ust-omchug
# Processing Record 20 of Set 1 | shebalino
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | husavik
# Processing Record 23 of Set 1 | fairbanks
# Processing Record 24 of Set 1 | thompson
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | adre
# Processing Record 27 of Set 1 | gornozavodsk
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | remontnoye
# Processing Record 31 of Set 1 | kudahuvadhoo
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | comodoro rivadavia
# Processing Record 34 of Set 1 | grand gaube
# Processing Record 35 of Set 1 | sataua
# City not found. Skipping...
# Processing Record 36 of Set 1 | yulara
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | ronne
# Processing Record 39 of Set 1 | havre-saint-pierre
# Processing Record 40 of Set 1 | butaritari
# Processing Record 41 of Set 1 | vernon
# Processing Record 42 of Set 1 | tilichiki
# Processing Record 43 of Set 1 | nanortalik
# Processing Record 44 of Set 1 | lorengau
# Processing Record 45 of Set 1 | provideniya
# Processing Record 46 of Set 1 | upata
# Processing Record 47 of Set 1 | cidreira
# Processing Record 48 of Set 1 | qaanaaq
# Processing Record 49 of Set 1 | east london
# Processing Record 50 of Set 1 | lebu
# Processing Record 1 of Set 2 | avarua
# Processing Record 2 of Set 2 | sao joao da barra
# Processing Record 3 of Set 2 | puerto ayora
# Processing Record 4 of Set 2 | hilo
# Processing Record 5 of Set 2 | hermanus
# Processing Record 6 of Set 2 | baykit
# Processing Record 7 of Set 2 | ponta do sol
# Processing Record 8 of Set 2 | wanaka
# Processing Record 9 of Set 2 | colac
# Processing Record 10 of Set 2 | mataura
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | mahon
# Processing Record 13 of Set 2 | cherskiy
# Processing Record 14 of Set 2 | faya
# Processing Record 15 of Set 2 | hofn
# Processing Record 16 of Set 2 | preston
# Processing Record 17 of Set 2 | chapais
# Processing Record 18 of Set 2 | port elizabeth
# Processing Record 19 of Set 2 | kontagora
# Processing Record 20 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 21 of Set 2 | robertsport
# Processing Record 22 of Set 2 | batemans bay
# Processing Record 23 of Set 2 | kavieng
# Processing Record 24 of Set 2 | lebyazhye
# Processing Record 25 of Set 2 | kapaa
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | kodiak
# Processing Record 28 of Set 2 | mirnyy
# Processing Record 29 of Set 2 | cabo san lucas
# Processing Record 30 of Set 2 | san jose de guanipa
# Processing Record 31 of Set 2 | maldonado
# Processing Record 32 of Set 2 | namibe
# Processing Record 33 of Set 2 | san fernando
# Processing Record 34 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 2 | saint george
# Processing Record 36 of Set 2 | rockland
# Processing Record 37 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 2 | ribas do rio pardo
# Processing Record 39 of Set 2 | pokhara
# Processing Record 40 of Set 2 | skjold
# Processing Record 41 of Set 2 | clyde river
# Processing Record 42 of Set 2 | el angel
# Processing Record 43 of Set 2 | broome
# Processing Record 44 of Set 2 | redmond
# Processing Record 45 of Set 2 | dom pedrito
# Processing Record 46 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 2 | olga
# Processing Record 48 of Set 2 | jacareacanga
# Processing Record 49 of Set 2 | meulaboh
# Processing Record 50 of Set 2 | gwadar
# Processing Record 1 of Set 3 | norman wells
# Processing Record 2 of Set 3 | tocopilla
# Processing Record 3 of Set 3 | bom jesus
# Processing Record 4 of Set 3 | muros
# Processing Record 5 of Set 3 | hami
# Processing Record 6 of Set 3 | riyadh
# Processing Record 7 of Set 3 | ostrovnoy
# Processing Record 8 of Set 3 | tuatapere
# Processing Record 9 of Set 3 | gaoual
# Processing Record 10 of Set 3 | mar del plata
# Processing Record 11 of Set 3 | longyearbyen
# Processing Record 12 of Set 3 | victoria
# Processing Record 13 of Set 3 | busselton
# Processing Record 14 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 3 | bengkulu
# Processing Record 16 of Set 3 | mantua
# Processing Record 17 of Set 3 | coihaique
# Processing Record 18 of Set 3 | ilulissat
# Processing Record 19 of Set 3 | constitucion
# Processing Record 20 of Set 3 | la ronge
# Processing Record 21 of Set 3 | uige
# Processing Record 22 of Set 3 | tarsus
# Processing Record 23 of Set 3 | kapchorwa
# Processing Record 24 of Set 3 | elizabeth city
# Processing Record 25 of Set 3 | dourbali
# Processing Record 26 of Set 3 | tiarei
# Processing Record 27 of Set 3 | lasa
# Processing Record 28 of Set 3 | maniitsoq
# Processing Record 29 of Set 3 | sinkat
# City not found. Skipping...
# Processing Record 30 of Set 3 | noyabrsk
# Processing Record 31 of Set 3 | beloha
# Processing Record 32 of Set 3 | okhotsk
# Processing Record 33 of Set 3 | san cristobal
# Processing Record 34 of Set 3 | atar
# Processing Record 35 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 3 | sembe
# Processing Record 37 of Set 3 | panalingaan
# Processing Record 38 of Set 3 | pitea
# Processing Record 39 of Set 3 | kalmunai
# Processing Record 40 of Set 3 | mahebourg
# Processing Record 41 of Set 3 | clinton
# Processing Record 42 of Set 3 | nago
# Processing Record 43 of Set 3 | tiznit
# Processing Record 44 of Set 3 | nikolskoye
# Processing Record 45 of Set 3 | bundaberg
# Processing Record 46 of Set 3 | bubaque
# Processing Record 47 of Set 3 | lata
# Processing Record 48 of Set 3 | bowen
# Processing Record 49 of Set 3 | pochutla
# Processing Record 50 of Set 3 | narsaq
# Processing Record 1 of Set 4 | saldanha
# Processing Record 2 of Set 4 | constantine
# Processing Record 3 of Set 4 | indiana
# Processing Record 4 of Set 4 | geraldton
# Processing Record 5 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 6 of Set 4 | saint-joseph
# Processing Record 7 of Set 4 | sitka
# Processing Record 8 of Set 4 | lang son
# Processing Record 9 of Set 4 | banmo
# City not found. Skipping...
# Processing Record 10 of Set 4 | khatanga
# Processing Record 11 of Set 4 | coquimbo
# Processing Record 12 of Set 4 | humaita
# Processing Record 13 of Set 4 | nim ka thana
# City not found. Skipping...
# Processing Record 14 of Set 4 | panjab
# Processing Record 15 of Set 4 | manitouwadge
# Processing Record 16 of Set 4 | hobyo
# Processing Record 17 of Set 4 | mocuba
# Processing Record 18 of Set 4 | pashiya
# Processing Record 19 of Set 4 | henties bay
# Processing Record 20 of Set 4 | brooks
# Processing Record 21 of Set 4 | kasempa
# Processing Record 22 of Set 4 | bababe
# City not found. Skipping...
# Processing Record 23 of Set 4 | tuktoyaktuk
# Processing Record 24 of Set 4 | altagracia de orituco
# Processing Record 25 of Set 4 | talnakh
# Processing Record 26 of Set 4 | ribeira grande
# Processing Record 27 of Set 4 | hamilton
# Processing Record 28 of Set 4 | ust-tsilma
# Processing Record 29 of Set 4 | upernavik
# Processing Record 30 of Set 4 | arraial do cabo
# Processing Record 31 of Set 4 | yabelo
# Processing Record 32 of Set 4 | isangel
# Processing Record 33 of Set 4 | haradok
# Processing Record 34 of Set 4 | oistins
# Processing Record 35 of Set 4 | flinders
# Processing Record 36 of Set 4 | pevek
# Processing Record 37 of Set 4 | saint-philippe
# Processing Record 38 of Set 4 | lavrentiya
# Processing Record 39 of Set 4 | takaungu
# Processing Record 40 of Set 4 | karakendzha
# City not found. Skipping...
# Processing Record 41 of Set 4 | erenhot
# Processing Record 42 of Set 4 | valparaiso
# Processing Record 43 of Set 4 | tasiilaq
# Processing Record 44 of Set 4 | bredasdorp
# Processing Record 45 of Set 4 | kota kinabalu
# Processing Record 46 of Set 4 | athenree
# Processing Record 47 of Set 4 | dawei
# Processing Record 48 of Set 4 | santa vitoria do palmar
# Processing Record 49 of Set 4 | tautira
# Processing Record 50 of Set 4 | rio grande
# Processing Record 1 of Set 5 | marzuq
# Processing Record 2 of Set 5 | chuy
# Processing Record 3 of Set 5 | svarstad
# Processing Record 4 of Set 5 | lompoc
# Processing Record 5 of Set 5 | torbay
# Processing Record 6 of Set 5 | grindavik
# Processing Record 7 of Set 5 | new norfolk
# Processing Record 8 of Set 5 | roald
# Processing Record 9 of Set 5 | pemangkat
# Processing Record 10 of Set 5 | floro
# Processing Record 11 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 12 of Set 5 | ilebo
# Processing Record 13 of Set 5 | salalah
# Processing Record 14 of Set 5 | marystown
# Processing Record 15 of Set 5 | dickinson
# Processing Record 16 of Set 5 | rio gallegos
# Processing Record 17 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 5 | puerto colombia
# Processing Record 19 of Set 5 | fenoarivo
# Processing Record 20 of Set 5 | portland
# Processing Record 21 of Set 5 | luan
# Processing Record 22 of Set 5 | trairi
# Processing Record 23 of Set 5 | danville
# Processing Record 24 of Set 5 | rocky mountain house
# Processing Record 25 of Set 5 | gravdal
# Processing Record 26 of Set 5 | mayskiy
# Processing Record 27 of Set 5 | wattegama
# Processing Record 28 of Set 5 | elko
# Processing Record 29 of Set 5 | pingzhuang
# Processing Record 30 of Set 5 | cabras
# Processing Record 31 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 5 | turayf
# Processing Record 33 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 5 | ancud
# Processing Record 36 of Set 5 | pisco
# Processing Record 37 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 38 of Set 5 | kursenai
# Processing Record 39 of Set 5 | poum
# Processing Record 40 of Set 5 | hovd
# Processing Record 41 of Set 5 | marawi
# Processing Record 42 of Set 5 | lexington
# Processing Record 43 of Set 5 | puerto montt
# Processing Record 44 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 5 | yaguajay
# Processing Record 46 of Set 5 | baghdad
# Processing Record 47 of Set 5 | arkhangelos
# City not found. Skipping...
# Processing Record 48 of Set 5 | kungurtug
# Processing Record 49 of Set 5 | luganville
# Processing Record 50 of Set 5 | srednekolymsk
# Processing Record 1 of Set 6 | chokurdakh
# Processing Record 2 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 6 | taburao
# City not found. Skipping...
# Processing Record 4 of Set 6 | thinadhoo
# Processing Record 5 of Set 6 | dikson
# Processing Record 6 of Set 6 | nevel
# Processing Record 7 of Set 6 | souillac
# Processing Record 8 of Set 6 | codrington
# Processing Record 9 of Set 6 | port lincoln
# Processing Record 10 of Set 6 | adamas
# Processing Record 11 of Set 6 | curuguaty
# Processing Record 12 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 13 of Set 6 | san quintin
# Processing Record 14 of Set 6 | ulladulla
# Processing Record 15 of Set 6 | crotone
# Processing Record 16 of Set 6 | arman
# Processing Record 17 of Set 6 | lazaro cardenas
# Processing Record 18 of Set 6 | kazachinskoye
# Processing Record 19 of Set 6 | gao
# Processing Record 20 of Set 6 | waipawa
# Processing Record 21 of Set 6 | tiksi
# Processing Record 22 of Set 6 | galle
# Processing Record 23 of Set 6 | san buenaventura
# Processing Record 24 of Set 6 | tanda
# Processing Record 25 of Set 6 | sioux lookout
# Processing Record 26 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 27 of Set 6 | newcastle
# Processing Record 28 of Set 6 | luderitz
# Processing Record 29 of Set 6 | palana
# Processing Record 30 of Set 6 | te anau
# Processing Record 31 of Set 6 | bairiki
# Processing Record 32 of Set 6 | anadyr
# Processing Record 33 of Set 6 | gazojak
# Processing Record 34 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 35 of Set 6 | kabare
# Processing Record 36 of Set 6 | siderno
# Processing Record 37 of Set 6 | porto novo
# Processing Record 38 of Set 6 | atikokan
# Processing Record 39 of Set 6 | barrow
# Processing Record 40 of Set 6 | airai
# Processing Record 41 of Set 6 | faanui
# Processing Record 42 of Set 6 | zubtsov
# Processing Record 43 of Set 6 | mendeleyevsk
# Processing Record 44 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 45 of Set 6 | panaba
# Processing Record 46 of Set 6 | bambous virieux
# Processing Record 47 of Set 6 | vila franca do campo
# Processing Record 48 of Set 6 | eenhana
# Processing Record 49 of Set 6 | fortuna
# Processing Record 50 of Set 6 | gamba
# Processing Record 1 of Set 7 | nijar
# Processing Record 2 of Set 7 | szentes
# Processing Record 3 of Set 7 | sokolo
# Processing Record 4 of Set 7 | slavutych
# Processing Record 5 of Set 7 | saskylakh
# Processing Record 6 of Set 7 | cayenne
# Processing Record 7 of Set 7 | bhindar
# Processing Record 8 of Set 7 | vestmanna
# Processing Record 9 of Set 7 | qandala
# Processing Record 10 of Set 7 | chara
# Processing Record 11 of Set 7 | morro bay
# Processing Record 12 of Set 7 | san andres
# Processing Record 13 of Set 7 | borogontsy
# Processing Record 14 of Set 7 | westport
# Processing Record 15 of Set 7 | tongliao
# Processing Record 16 of Set 7 | tianpeng
# Processing Record 17 of Set 7 | willmar
# Processing Record 18 of Set 7 | jahrom
# City not found. Skipping...
# Processing Record 19 of Set 7 | brainerd
# Processing Record 20 of Set 7 | nantucket
# Processing Record 21 of Set 7 | leningradskiy
# Processing Record 22 of Set 7 | nemuro
# Processing Record 23 of Set 7 | college
# Processing Record 24 of Set 7 | boguchany
# Processing Record 25 of Set 7 | madimba
# Processing Record 26 of Set 7 | mpika
# Processing Record 27 of Set 7 | nangong
# Processing Record 28 of Set 7 | nanakuli
# Processing Record 29 of Set 7 | point pedro
# Processing Record 30 of Set 7 | beira
# Processing Record 31 of Set 7 | sao filipe
# Processing Record 32 of Set 7 | bethel
# Processing Record 33 of Set 7 | puerto escondido
# Processing Record 34 of Set 7 | icod de los vinos
# Processing Record 35 of Set 7 | hvolsvollur
# Processing Record 36 of Set 7 | komsomolskiy
# Processing Record 37 of Set 7 | borodino
# Processing Record 38 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 7 | sibu
# Processing Record 40 of Set 7 | nome
# Processing Record 41 of Set 7 | oranjemund
# Processing Record 42 of Set 7 | kahului
# Processing Record 43 of Set 7 | carnarvon
# Processing Record 44 of Set 7 | phangnga
# Processing Record 45 of Set 7 | honiara
# Processing Record 46 of Set 7 | abalak
# Processing Record 47 of Set 7 | jibuti
# Processing Record 48 of Set 7 | fairlie
# Processing Record 49 of Set 7 | saint-augustin
# Processing Record 50 of Set 7 | broken hill
# Processing Record 1 of Set 8 | galesong
# Processing Record 2 of Set 8 | kanel
# Processing Record 3 of Set 8 | miri
# Processing Record 4 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 8 | podgornoye
# Processing Record 6 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 8 | ilyich
# Processing Record 8 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 8 | opuwo
# Processing Record 10 of Set 8 | savinka
# Processing Record 11 of Set 8 | bilma
# Processing Record 12 of Set 8 | kruisfontein
# Processing Record 13 of Set 8 | kulhudhuffushi
# Processing Record 14 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 8 | port macquarie
# Processing Record 16 of Set 8 | wawa
# Processing Record 17 of Set 8 | yar-sale
# Processing Record 18 of Set 8 | eyl
# Processing Record 19 of Set 8 | esperance
# Processing Record 20 of Set 8 | gragnano
# Processing Record 21 of Set 8 | mangrol
# Processing Record 22 of Set 8 | port hawkesbury
# Processing Record 23 of Set 8 | gornopravdinsk
# Processing Record 24 of Set 8 | kutum
# Processing Record 25 of Set 8 | zhigalovo
# Processing Record 26 of Set 8 | acarau
# Processing Record 27 of Set 8 | nouadhibou
# Processing Record 28 of Set 8 | udachnyy
# Processing Record 29 of Set 8 | katangli
# Processing Record 30 of Set 8 | vila do maio
# Processing Record 31 of Set 8 | konosha
# Processing Record 32 of Set 8 | ingham
# Processing Record 33 of Set 8 | wajima
# Processing Record 34 of Set 8 | korla
# Processing Record 35 of Set 8 | kosice
# Processing Record 36 of Set 8 | port keats
# Processing Record 37 of Set 8 | leninskoye
# Processing Record 38 of Set 8 | kununurra
# Processing Record 39 of Set 8 | waiouru
# Processing Record 40 of Set 8 | tshane
# Processing Record 41 of Set 8 | seoul
# Processing Record 42 of Set 8 | lakatoro
# Processing Record 43 of Set 8 | kavaratti
# Processing Record 44 of Set 8 | woodstock
# Processing Record 45 of Set 8 | mezen
# Processing Record 46 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 8 | mount gambier
# Processing Record 48 of Set 8 | mokhsogollokh
# Processing Record 49 of Set 8 | touros
# Processing Record 50 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 9 | makakilo city
# Processing Record 2 of Set 9 | mount isa
# Processing Record 3 of Set 9 | acapetahua
# Processing Record 4 of Set 9 | ngunguru
# Processing Record 5 of Set 9 | cockburn town
# Processing Record 6 of Set 9 | tel aviv-yafo
# Processing Record 7 of Set 9 | yumen
# Processing Record 8 of Set 9 | ihlow
# Processing Record 9 of Set 9 | guerrero negro
# Processing Record 10 of Set 9 | khotyn
# Processing Record 11 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 9 | talcahuano
# Processing Record 13 of Set 9 | waw
# Processing Record 14 of Set 9 | maceio
# Processing Record 15 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 16 of Set 9 | port blair
# Processing Record 17 of Set 9 | ahuimanu
# Processing Record 18 of Set 9 | severo-kurilsk
# Processing Record 19 of Set 9 | strone
# Processing Record 20 of Set 9 | haines junction
# Processing Record 21 of Set 9 | caravelas
# Processing Record 22 of Set 9 | iqaluit
# Processing Record 23 of Set 9 | pecos
# Processing Record 24 of Set 9 | brae
# Processing Record 25 of Set 9 | dodoma
# Processing Record 26 of Set 9 | ustyuzhna
# Processing Record 27 of Set 9 | ust-maya
# Processing Record 28 of Set 9 | hannibal
# Processing Record 29 of Set 9 | moron
# Processing Record 30 of Set 9 | bilibino
# Processing Record 31 of Set 9 | tulun
# Processing Record 32 of Set 9 | kantunilkin
# Processing Record 33 of Set 9 | hervey bay
# Processing Record 34 of Set 9 | foam lake
# Processing Record 35 of Set 9 | naples park
# Processing Record 36 of Set 9 | baruun-urt
# Processing Record 37 of Set 9 | poyarkovo
# Processing Record 38 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 39 of Set 9 | marsa matruh
# Processing Record 40 of Set 9 | buenavista
# Processing Record 41 of Set 9 | yangjiang
# Processing Record 42 of Set 9 | katsuura
# Processing Record 43 of Set 9 | ambanja
# Processing Record 44 of Set 9 | dzaoudzi
# Processing Record 45 of Set 9 | santarem
# Processing Record 46 of Set 9 | olinda
# Processing Record 47 of Set 9 | vangaindrano
# Processing Record 48 of Set 9 | san vicente
# Processing Record 49 of Set 9 | mahajanga
# Processing Record 50 of Set 9 | provost
# Processing Record 1 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 10 | elban
# Processing Record 3 of Set 10 | kaeo
# Processing Record 4 of Set 10 | hidalgo
# Processing Record 5 of Set 10 | alcamo
# Processing Record 6 of Set 10 | asau
# Processing Record 7 of Set 10 | riachao do dantas
# Processing Record 8 of Set 10 | selma
# Processing Record 9 of Set 10 | pidhorodne
# Processing Record 10 of Set 10 | chitungwiza
# Processing Record 11 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 12 of Set 10 | viesite
# Processing Record 13 of Set 10 | cerrito
# Processing Record 14 of Set 10 | hualmay
# Processing Record 15 of Set 10 | tabas
# Processing Record 16 of Set 10 | mitu
# Processing Record 17 of Set 10 | sola
# Processing Record 18 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 10 | eureka
# Processing Record 20 of Set 10 | klaksvik
# Processing Record 21 of Set 10 | aasiaat
# Processing Record 22 of Set 10 | gogrial
# Processing Record 23 of Set 10 | salym
# Processing Record 24 of Set 10 | fayetteville
# Processing Record 25 of Set 10 | sept-iles
# Processing Record 26 of Set 10 | barabai
# Processing Record 27 of Set 10 | namtsy
# Processing Record 28 of Set 10 | brandfort
# Processing Record 29 of Set 10 | tashara
# Processing Record 30 of Set 10 | dingle
# Processing Record 31 of Set 10 | great yarmouth
# Processing Record 32 of Set 10 | boden
# Processing Record 33 of Set 10 | praia da vitoria
# Processing Record 34 of Set 10 | shikhany
# Processing Record 35 of Set 10 | nargana
# Processing Record 36 of Set 10 | puerto leguizamo
# Processing Record 37 of Set 10 | lamu
# Processing Record 38 of Set 10 | turukhansk
# Processing Record 39 of Set 10 | mundo nuevo
# Processing Record 40 of Set 10 | dunedin
# Processing Record 41 of Set 10 | mokolo
# Processing Record 42 of Set 10 | tambun
# Processing Record 43 of Set 10 | sooke
# Processing Record 44 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 45 of Set 10 | ixtapa
# Processing Record 46 of Set 10 | tahoua
# Processing Record 47 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 48 of Set 10 | houma
# Processing Record 49 of Set 10 | vestmannaeyjar
# Processing Record 50 of Set 10 | carauari
# Processing Record 1 of Set 11 | konch
# Processing Record 2 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 3 of Set 11 | ossora
# Processing Record 4 of Set 11 | mrakovo
# Processing Record 5 of Set 11 | havoysund
# Processing Record 6 of Set 11 | batagay-alyta
# Processing Record 7 of Set 11 | evensk
# Processing Record 8 of Set 11 | frankfort
# Processing Record 9 of Set 11 | mabaruma
# Processing Record 10 of Set 11 | mizdah
# Processing Record 11 of Set 11 | dudinka
# Processing Record 12 of Set 11 | bar harbor
# Processing Record 13 of Set 11 | kichera
# Processing Record 14 of Set 11 | kracheh
# City not found. Skipping...
# Processing Record 15 of Set 11 | mackenzie
# Processing Record 16 of Set 11 | raga
# Processing Record 17 of Set 11 | hasaki
# Processing Record 18 of Set 11 | scarborough
# Processing Record 19 of Set 11 | namatanai
# Processing Record 20 of Set 11 | visim
# Processing Record 21 of Set 11 | kawana waters
# City not found. Skipping...
# Processing Record 22 of Set 11 | torbat-e jam
# Processing Record 23 of Set 11 | derna
# Processing Record 24 of Set 11 | san policarpo
# Processing Record 25 of Set 11 | pacific grove
# Processing Record 26 of Set 11 | port augusta
# Processing Record 27 of Set 11 | polyanka
# Processing Record 28 of Set 11 | loa janan
# Processing Record 29 of Set 11 | sundby
# Processing Record 30 of Set 11 | pilar
# Processing Record 31 of Set 11 | vilyuysk
# Processing Record 32 of Set 11 | jacmel
# Processing Record 33 of Set 11 | kathmandu
# Processing Record 34 of Set 11 | qaqortoq
# Processing Record 35 of Set 11 | zhigansk
# Processing Record 36 of Set 11 | belaya gora
# Processing Record 37 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 38 of Set 11 | sishui
# Processing Record 39 of Set 11 | ketchikan
# Processing Record 40 of Set 11 | nara
# Processing Record 41 of Set 11 | vilhena
# Processing Record 42 of Set 11 | baryshivka
# Processing Record 43 of Set 11 | ballarat
# Processing Record 44 of Set 11 | sechura
# Processing Record 45 of Set 11 | abnub
# Processing Record 46 of Set 11 | saint-francois
# Processing Record 47 of Set 11 | whitehorse
# Processing Record 48 of Set 11 | peniche
# Processing Record 49 of Set 11 | kathu
# Processing Record 50 of Set 11 | belmonte
# Processing Record 1 of Set 12 | winnemucca
# Processing Record 2 of Set 12 | keffi
# Processing Record 3 of Set 12 | shar
# Processing Record 4 of Set 12 | tsuyama
# Processing Record 5 of Set 12 | damietta
# Processing Record 6 of Set 12 | champerico
# Processing Record 7 of Set 12 | mennecy
# Processing Record 8 of Set 12 | sawakin
# Processing Record 9 of Set 12 | jabinyanah
# Processing Record 10 of Set 12 | necochea
# Processing Record 11 of Set 12 | mecca
# Processing Record 12 of Set 12 | suraabad
# Processing Record 13 of Set 12 | sistranda
# Processing Record 14 of Set 12 | aksu
# Processing Record 15 of Set 12 | seguela
# Processing Record 16 of Set 12 | basco
# Processing Record 17 of Set 12 | locri
# Processing Record 18 of Set 12 | aras
# Processing Record 19 of Set 12 | santa cruz
# Processing Record 20 of Set 12 | vanimo
# Processing Record 21 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 22 of Set 12 | russell
# Processing Record 23 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 24 of Set 12 | itarema
# Processing Record 25 of Set 12 | mao
# Processing Record 26 of Set 12 | pallisa
# Processing Record 27 of Set 12 | segezha
# Processing Record 28 of Set 12 | pryazha
# Processing Record 29 of Set 12 | harper
# Processing Record 30 of Set 12 | bullhead city
# Processing Record 31 of Set 12 | bonga
# Processing Record 32 of Set 12 | conde
# Processing Record 33 of Set 12 | kendari
# Processing Record 34 of Set 12 | coueron
# Processing Record 35 of Set 12 | savannah bight
# Processing Record 36 of Set 12 | san jose
# Processing Record 37 of Set 12 | shenjiamen
# Processing Record 38 of Set 12 | lagoa
# Processing Record 39 of Set 12 | gondanglegi
# Processing Record 40 of Set 12 | yerbogachen
# Processing Record 41 of Set 12 | cam pha
# City not found. Skipping...
# Processing Record 42 of Set 12 | sirnak
# Processing Record 43 of Set 12 | fort nelson
# Processing Record 44 of Set 12 | woodward
# Processing Record 45 of Set 12 | kamen-rybolov
# Processing Record 46 of Set 12 | thai binh
# Processing Record 47 of Set 12 | kirakira
# Processing Record 48 of Set 12 | sampit
# Processing Record 49 of Set 12 | sosnovo-ozerskoye
# Processing Record 50 of Set 12 | naze
# Processing Record 1 of Set 13 | fengzhen
# Processing Record 2 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 3 of Set 13 | gat
# Processing Record 4 of Set 13 | beringovskiy
# Processing Record 5 of Set 13 | tres lagoas
# Processing Record 6 of Set 13 | paralimni
# Processing Record 7 of Set 13 | le port
# Processing Record 8 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 9 of Set 13 | hay river
# Processing Record 10 of Set 13 | killybegs
# Processing Record 11 of Set 13 | ibra
# Processing Record 12 of Set 13 | poronaysk
# Processing Record 13 of Set 13 | maningrida
# Processing Record 14 of Set 13 | kenora
# Processing Record 15 of Set 13 | khudumelapye
# Processing Record 16 of Set 13 | meghraj
# Processing Record 17 of Set 13 | phuket
# Processing Record 18 of Set 13 | areosa
# Processing Record 19 of Set 13 | kropotkin
# Processing Record 20 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 21 of Set 13 | reus
# Processing Record 22 of Set 13 | tyukalinsk
# Processing Record 23 of Set 13 | port hardy
# Processing Record 24 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 25 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 26 of Set 13 | laguna
# Processing Record 27 of Set 13 | gordeyevka
# Processing Record 28 of Set 13 | bembereke
# Processing Record 29 of Set 13 | kisanga
# Processing Record 30 of Set 13 | suhbaatar
# Processing Record 31 of Set 13 | avera
# Processing Record 32 of Set 13 | port-gentil
# Processing Record 33 of Set 13 | manggar
# Processing Record 34 of Set 13 | somerset
# Processing Record 35 of Set 13 | oriximina
# Processing Record 36 of Set 13 | hambantota
# Processing Record 37 of Set 13 | svetlyy
# Processing Record 38 of Set 13 | yablochnyy
# Processing Record 39 of Set 13 | sibolga
# Processing Record 40 of Set 13 | salgado
# Processing Record 41 of Set 13 | baltasi
# Processing Record 42 of Set 13 | jining
# Processing Record 43 of Set 13 | trat
# Processing Record 44 of Set 13 | tommot
# Processing Record 45 of Set 13 | leshukonskoye
# Processing Record 46 of Set 13 | menongue
# Processing Record 47 of Set 13 | pocone
# Processing Record 48 of Set 13 | azangaro
# Processing Record 49 of Set 13 | shache
# Processing Record 50 of Set 13 | vacaria
# Processing Record 1 of Set 14 | kangaatsiaq
# Processing Record 2 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 3 of Set 14 | alice springs
# Processing Record 4 of Set 14 | xinyu
# Processing Record 5 of Set 14 | tvardica
# City not found. Skipping...
# Processing Record 6 of Set 14 | buraydah
# Processing Record 7 of Set 14 | villazon
# Processing Record 8 of Set 14 | enugu
# Processing Record 9 of Set 14 | naftah
# City not found. Skipping...
# Processing Record 10 of Set 14 | egvekinot
# Processing Record 11 of Set 14 | olafsvik
# Processing Record 12 of Set 14 | predivinsk
# Processing Record 13 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 14 of Set 14 | kloulklubed
# Processing Record 15 of Set 14 | darnah
# Processing Record 16 of Set 14 | staryy nadym
# Processing Record 17 of Set 14 | vostok
# Processing Record 18 of Set 14 | mackay
# Processing Record 19 of Set 14 | natal
# Processing Record 20 of Set 14 | sigulda
# Processing Record 21 of Set 14 | vardo
# Processing Record 22 of Set 14 | atasu
# Processing Record 23 of Set 14 | palmer
# Processing Record 24 of Set 14 | bonavista
# Processing Record 25 of Set 14 | flin flon
# Processing Record 26 of Set 14 | berlevag
# Processing Record 27 of Set 14 | deputatskiy
# Processing Record 28 of Set 14 | milas
# Processing Record 29 of Set 14 | tura
# Processing Record 30 of Set 14 | rabak
# Processing Record 31 of Set 14 | palasa
# Processing Record 32 of Set 14 | irtyshskiy
# Processing Record 33 of Set 14 | praia
# Processing Record 34 of Set 14 | padang
# Processing Record 35 of Set 14 | tomatlan
# Processing Record 36 of Set 14 | samarai
# Processing Record 37 of Set 14 | imisli
# City not found. Skipping...
# Processing Record 38 of Set 14 | high level
# Processing Record 39 of Set 14 | thohoyandou
# Processing Record 40 of Set 14 | coos bay
# Processing Record 41 of Set 14 | sabang
# Processing Record 42 of Set 14 | fairhaven
# Processing Record 43 of Set 14 | solnechnyy
# Processing Record 44 of Set 14 | senno
# Processing Record 45 of Set 14 | lat yao
# Processing Record 46 of Set 14 | letlhakane
# Processing Record 47 of Set 14 | taburi
# City not found. Skipping...
# Processing Record 48 of Set 14 | tabuk
# Processing Record 49 of Set 14 | leshan
# Processing Record 50 of Set 14 | matagami
# Processing Record 1 of Set 15 | north las vegas
# Processing Record 2 of Set 15 | koutsouras
# Processing Record 3 of Set 15 | jiexiu
# Processing Record 4 of Set 15 | tambo
# Processing Record 5 of Set 15 | phan thiet
# Processing Record 6 of Set 15 | kasulu
# Processing Record 7 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 15 | kuytun
# Processing Record 9 of Set 15 | sayat
# Processing Record 10 of Set 15 | butler
# Processing Record 11 of Set 15 | sakaiminato
# Processing Record 12 of Set 15 | la seyne-sur-mer
# Processing Record 13 of Set 15 | ouesso
# Processing Record 14 of Set 15 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 15 of Set 15 | alofi
# Processing Record 16 of Set 15 | taoudenni
# Processing Record 17 of Set 15 | ambunti
# Processing Record 18 of Set 15 | popondetta
# Processing Record 19 of Set 15 | gillette
# Processing Record 20 of Set 15 | ussel
# Processing Record 21 of Set 15 | esfarayen
# Processing Record 22 of Set 15 | swift current
# Processing Record 23 of Set 15 | novikovo
# Processing Record 24 of Set 15 | anton lizardo
# Processing Record 25 of Set 15 | falmouth
# Processing Record 26 of Set 15 | nizwa
# Processing Record 27 of Set 15 | linjiang
# Processing Record 28 of Set 15 | edd
# Processing Record 29 of Set 15 | polunochnoye
# Processing Record 30 of Set 15 | abay
# Processing Record 31 of Set 15 | erdenet
# Processing Record 32 of Set 15 | little current
# Processing Record 33 of Set 15 | gilbues
# Processing Record 34 of Set 15 | hailar
# Processing Record 35 of Set 15 | port arthur
# Processing Record 36 of Set 15 | yeppoon
# Processing Record 37 of Set 15 | santa ines
# Processing Record 38 of Set 15 | tawang
# Processing Record 39 of Set 15 | cabra
# Processing Record 40 of Set 15 | sisimiut
# Processing Record 41 of Set 15 | dobroye
# Processing Record 42 of Set 15 | smithers
# Processing Record 43 of Set 15 | tomaszow lubelski
# Processing Record 44 of Set 15 | nogales
# Processing Record 45 of Set 15 | kanganpur
# Processing Record 46 of Set 15 | tateyama
# Processing Record 47 of Set 15 | biak
# Processing Record 48 of Set 15 | hohhot
# Processing Record 49 of Set 15 | san juan
# Processing Record 50 of Set 15 | omsukchan
# Processing Record 1 of Set 16 | rawson
# Processing Record 2 of Set 16 | helong
# Processing Record 3 of Set 16 | tessalit
# Processing Record 4 of Set 16 | orbetello
# Processing Record 5 of Set 16 | maarianhamina
# Processing Record 6 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 16 | masuda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 689

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0        Rikitea      PF  2022-10-05 19:22:59 -23.1203 -134.9692     69.57
# 1     Kaitangata      NZ  2022-10-05 19:23:02 -46.2817  169.8464     36.43
# 2         Albany      US  2022-10-05 19:23:12  42.6001  -73.9662     63.88
# 3      Cape Town      ZA  2022-10-05 19:24:46 -33.9258   18.4232     60.89
# 4     Vila Velha      BR  2022-10-05 19:26:42 -20.3297  -40.2925     76.95
# 5         Hobart      AU  2022-10-05 19:21:56 -42.8794  147.3294     48.25
# 6   Punta Arenas      CL  2022-10-05 19:23:59 -53.1500  -70.9167     53.71
# 7        Ahipara      NZ  2022-10-05 19:23:09 -35.1667  173.1667     52.83
# 8      Hithadhoo      MV  2022-10-05 19:26:43  -0.6000   73.0833     82.40
# 9  Alto Araguaia      BR  2022-10-05 19:26:43 -17.3147  -53.2153     80.17
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        59           0       21.23           clear sky
# 1        80         100       14.61     overcast clouds
# 2        79         100        3.71     overcast clouds
# 3        65           0        7.00           clear sky
# 4        83          75        8.05       broken clouds
# 5        84          75        9.22       broken clouds
# 6        43          75       16.11       broken clouds
# 7        70         100       19.08     overcast clouds
# 8        73         100       17.56     overcast clouds
# 9        60          87        4.97     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed", "Current Description"]


# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Rikitea      PF -23.1203 -134.9692     69.57        59           0
# 1     Kaitangata      NZ -46.2817  169.8464     36.43        80         100
# 2         Albany      US  42.6001  -73.9662     63.88        79         100
# 3      Cape Town      ZA -33.9258   18.4232     60.89        65           0
# 4     Vila Velha      BR -20.3297  -40.2925     76.95        83          75
# 5         Hobart      AU -42.8794  147.3294     48.25        84          75
# 6   Punta Arenas      CL -53.1500  -70.9167     53.71        43          75
# 7        Ahipara      NZ -35.1667  173.1667     52.83        70         100
# 8      Hithadhoo      MV  -0.6000   73.0833     82.40        73         100
# 9  Alto Araguaia      BR -17.3147  -53.2153     80.17        60          87
#
#    Wind Speed Current Description
# 0       21.23           clear sky
# 1       14.61     overcast clouds
# 2        3.71     overcast clouds
# 3        7.00           clear sky
# 4        8.05       broken clouds
# 5        9.22       broken clouds
# 6       16.11       broken clouds
# 7       19.08     overcast clouds
# 8       17.56     overcast clouds
# 9        4.97     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
csv_weather_file = "weatherpy_database.csv"
# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
